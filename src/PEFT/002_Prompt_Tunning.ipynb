# %% [markdown]
# # 微调分类
#
# ![哔哩哔哩 2025-05-19 10.32.10.png](<attachment:哔哩哔哩 2025-05-19 10.32.10.png>)
#
# ## 人工添加提示词和自动训练的虚拟提示词的区别
# ![image.png](attachment:image.png)
#
# ## soft Prompt tuning具体原理
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 疑问 如何把这个向量放在已有的模型中，或者起作用

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 多任务模型的soft prompt
# ![image.png](attachment:image.png)
